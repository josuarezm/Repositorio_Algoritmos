# %%
# Python program to demonstrate searching operation
# in binary search tree without recursion
class newNode:
 
    # Constructor to create a new node
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
 
# Function to check the given
# key exist or not
def iterativeSearch(root, key, counter):
     
    # Traverse until root reaches
    # to dead end
    while root != None:
         
        # pass right subtree as new tree
        if key > root.data:
            root = root.right
            counter.append(1)
 
        # pass left subtree as new tree
        elif key < root.data:
            root = root.left
            counter.append(0)
        else:
            return True # if the key is found return 1
    return False
 
# A utility function to insert a
# new Node with given key in BST
def insert(Node, data):
     
    # If the tree is empty, return
    # a new Node
    if Node == None:
        return newNode(data)
 
    # Otherwise, recur down the tree
    if data < Node.data:
        Node.left = insert(Node.left, data)
    elif data > Node.data:
        Node.right = insert(Node.right, data)
 
    # return the (unchanged) Node pointer
    return Node

def print2DTree(root, space=0, LEVEL_SPACE = 5):
    if (root == None): return
    space += LEVEL_SPACE
    print2DTree(root.right, space)
    # print() # neighbor space
    for i in range(LEVEL_SPACE, space): print(end = " ")  
    if root.data==input_busqueda:
        print(chr(27)+"[1;32m"+"|" + str(root.data) + "|<") 
    elif root.data in ruta_lista:
        print(chr(27)+"[1;33m"+"|" + str(root.data) + "|<") 
    else:
        print(chr(27)+"[1;37m"+"|" + str(root.data) + "|<") 
    print2DTree(root.left, space)
        
# Driver Code
if __name__ == '__main__':
     
    input_raiz = int(input("Ingrese el valor raíz para la generación del árbol binario: "))
    input_nodos = int(input("Ingrese la cantidad de nodos para la generación del árbol binario (incluyendo la raíz): "))
    root = None
    root = insert(root, input_raiz)
    counter = []
    for i in range(input_nodos-1):
      input_nodo = int(input("Ingrese el valor (" + str(i+1) + "): "))
      insert(root, input_nodo)
    input_busqueda = int(input("Ingrese el valor que desea buscar en el árbol: "))
    if iterativeSearch(root, input_busqueda, counter):
      print("La ruta del valor buscado desde el origen es: ", end="")
      ruta_lista=[]
      for i in range(len(counter)):
        if counter[i] == 0:
          ruta_lista.append("Izquierda")
        else:
          ruta_lista.append("Derecha")
      print("-".join(ruta_lista))
    else:
        print("Nodo no encontrado")
    print("\n")
    print2DTree(root)
 
# This code is contributed by PranchalK
# Out:
# Ingrese el valor raíz para la generación del árbol binario: 5
# Ingrese la cantidad de nodos para la generación del árbol binario (incluyendo la raíz): 4
# Ingrese el valor (1): 3
# Ingrese el valor (2): 8
# Ingrese el valor (3): 20
# Ingrese el valor que desea buscar en el árbol: 20
# La ruta del valor buscado desde el origen es: Derecha-Derecha
#
#
#           |20|<
#      |8|<
# |5|<
#      |3|<

# %%
# Python program to demonstrate searching operation
# in binary search tree without recursion
class newNode:
 
    # Constructor to create a new node
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
 
# Function to check the given
# key exist or not
def iterativeSearch(root, key, counter):
     
    # Traverse until root reaches
    # to dead end
    check=False
    ruta=[]
    while root != None:
        if key == root.data:
            ruta.append(root.data)
            check=True
            break
             # if the key is found return 1
        # pass right subtree as new tree
        elif key > root.data:
            ruta.append(root.data)
            root = root.right
            counter.append(1)
            
 
        # pass left subtree as new tree
        elif key < root.data:
            ruta.append(root.data)
            root = root.left
            counter.append(0)
            
    if check != False:
      print("La ruta del valor buscado desde el origen es: ", end="")
      ruta_lista=[]
      for i in range(len(counter)):
        if counter[i] == 0:
          ruta_lista.append("Izquierda")
        else:
          ruta_lista.append("Derecha")
      print("-".join(ruta_lista))
    else:
        print("Nodo no encontrado")
    return ruta

 
# A utility function to insert a
# new Node with given key in BST
def insert(Node, data):
     
    # If the tree is empty, return
    # a new Node
    if Node == None:
        return newNode(data)
 
    # Otherwise, recur down the tree
    if data < Node.data:
        Node.left = insert(Node.left, data)
    elif data > Node.data:
        Node.right = insert(Node.right, data)
 
    # return the (unchanged) Node pointer
    return Node

def print2DTree(root, space=0, LEVEL_SPACE = 5):
    if (root == None): return
    space += LEVEL_SPACE
    print2DTree(root.right, space)
    # print() # neighbor space
    for i in range(LEVEL_SPACE, space): print(end = " ")  
    if root.data==input_busqueda:
        print(chr(27)+"[1;32m"+"|" + str(root.data) + "|<") 
    elif root.data in busqueda:
        print(chr(27)+"[1;33m"+"|" + str(root.data) + "|<") 
    else:
        print(chr(27)+"[1;37m"+"|" + str(root.data) + "|<") 
    print2DTree(root.left, space)
        
# Driver Code
if __name__ == '__main__':
     
    input_raiz = int(input("Ingrese el valor raíz para la generación del árbol binario: "))
    input_nodos = int(input("Ingrese la cantidad de nodos para la generación del árbol binario (incluyendo la raíz): "))
    root = None
    root = insert(root, input_raiz)
    counter = []
    for i in range(input_nodos-1):
      input_nodo = int(input("Ingrese el valor (" + str(i+1) + "): "))
      insert(root, input_nodo)
    input_busqueda = int(input("Ingrese el valor que desea buscar en el árbol: "))
    busqueda=iterativeSearch(root, input_busqueda, counter)
    print("\n")
    print2DTree(root)
 
# This code is contributed by PranchalK
# Out:
# Ingrese el valor raíz para la generación del árbol binario: 5
# Ingrese la cantidad de nodos para la generación del árbol binario (incluyendo la raíz): 5
# Ingrese el valor (1): 1
# Ingrese el valor (2): 2
# Ingrese el valor (3): 3
# Ingrese el valor (4): 8
# Ingrese el valor que desea buscar en el árbol: 3
# La ruta del valor buscado desde el origen es: Izquierda-Derecha-Derecha
#
#
#      |8|<
# |5|<
#                |3|<
#           |2|<
#      |1|<

# %%
print(chr(27)+"[1;32m"+"Texto en negrita de color verde") 
print("PRUEBA")
print(chr(27)+"[1;33m"+"Texto en negrita de color amarillo") 
print(chr(27)+"[1;31m"+"Texto en negrita de color rojo")
# Out:
# Texto en negrita de color verde
# PRUEBA
# Texto en negrita de color amarillo
# Texto en negrita de color rojo
